# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelghiorzi/S-AES/blob/main/saes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 1 e 2: Implementação S-AES e modo de operação ECB

# %% [markdown]
# A Classe SAES serve como um conjunto das funções necessárias para a implementação do algoritmo S-AES ou Simple AES

# %%
import base64

# %%
class SAES:
    def __init__(self):
        self.sbox = [
            [0x9, 0x4, 0xa, 0xb],
            [0xd, 0x1, 0x8, 0x5],
            [0x6, 0x2, 0x0, 0x3],
            [0xc, 0xe, 0xf, 0x7]
        ]

        # Inverse S-Box for decryption
        self.inv_sbox = [
            [0xa, 0x5, 0x9, 0xb],
            [0x1, 0x7, 0x8, 0xf],
            [0x6, 0x0, 0x2, 0x3],
            [0xc, 0x4, 0xd, 0xe]
        ]

        self.rcon1 = 0x80
        self.rcon2 = 0x30

    def print_state(self, state: list, title: str):
        """
        This prints the 16-bit state in a 2x2 matrix format
        """
        print(f"\033[93m{title}:\033[0m")
        print(f"\033[91m┌─────┬─────┐\033[0m")
        print(f"\033[91m│\033[0m {state[0]:02X}  \033[91m│\033[0m {state[1]:02X}  \033[91m│\033[0m")
        print(f"\033[91m├─────┼─────┤\033[0m")
        print(f"\033[91m│\033[0m {state[2]:02X}  \033[91m│\033[0m {state[3]:02X}  \033[91m│\033[0m")
        print(f"\033[91m└─────┴─────┘\033[0m")

    def expand_key(self, key: int):
        """
        This generates the 3 keys for SAES
        Each key is a list of 4 nibbles
        Returns:
            key0, key1, key2: int
        """
        print(f"")
        print(f"\n→ Starting key expansion with key: {key:04X}")

        # First, convert key into 4 nibbles
        w = []
        w.append((key >> 12) & 0xF) # w0
        w.append((key >> 8) & 0xF)  # w1
        w.append((key >> 4) & 0xF)  # w2
        w.append(key & 0xF)         # w3

        # Key 0 is the original key
        key0 = [w[0], w[1], w[2], w[3]]

        # Generate round key 1
        w4 = w[0] ^ self.substitute_nibbles(w[3], self.sbox) ^ (self.rcon1 >> 4)
        w5 = w[1] ^ self.substitute_nibbles(w[0], self.sbox) ^ (self.rcon1 & 0xF)
        w6 = w[2] ^ w4
        w7 = w[3] ^ w5
        key1 = [w4, w5, w6, w7]

        # Generate round key 2
        w8 = w4 ^ self.substitute_nibbles(w7, self.sbox) ^ (self.rcon2 >> 4)
        w9 = w5 ^ self.substitute_nibbles(w6, self.sbox) ^ (self.rcon2 & 0xF)
        w10 = w6 ^ w8
        w11 = w7 ^ w9
        key2 = [w8, w9, w10, w11]

        print(f"← Key expansion complete")
        return key0, key1, key2

    def add_round_key(self, state: list, key: list) -> list:
        """
        This XORs the state with the key
        XOR nibble by nibble

        Returns:
            new_state: list
        """
        print(f"\n→ Adding round key:")

        new_state = []
        for i in range(4):
            # iterating through each nibble
            new_nibble = state[i] ^ key[i]
            new_state.append(new_nibble)

        print(f"← Add Round Key complete")
        return new_state

    def substitute_nibbles(self, state: list, sbox: list[list]) -> list:
        """
        This applies substitution using the provided S-Box
        on the entire state, nibble by nibble.

        Returns:
            new_state: list or int (if single nibble)
        """
        print(f"\n→ Substituting nibbles:")

        if isinstance(state, int):
            nibble = state
            row = (nibble >> 2) & 0x3
            col = nibble & 0x3
            new_nibble = sbox[row][col]
            print(f"← Substitution complete")
            return new_nibble

        new_state = []
        for nibble in state:
            row = (nibble >> 2) & 0x3 # upper 2 bits for row
            col = nibble & 0x3 # lower 2 bits for column
            new_nibble = sbox[row][col]
            new_state.append(new_nibble)

        print(f"← Substitution complete")
        return new_state

    def shift_rows(self, state: list) -> list:
        """
        This shifts the rows of the state
        the bottom row is shifted

        Returns:
            new_state: list
        """

        print(f"\n→ Shifting rows:")

        new_state = [state[0], state[1], state[3], state[2]]

        print(f"← Shift Rows complete")
        return new_state

    def gf_multiply(self, a: int, b: int) -> int:
        """
        This performs Galois Field multiplication of two 4-bit numbers

        Returns:
            result: int
        """
        result = 0
        for i in range(4):      # process 4 bits of b
            if b & 1:           # if current bit of b is 1
                result ^= a     # Add current value of a to result
            high_bit = a & 0x8  # Check if a will overflow
            a <<= 1             # Shift a left by 1 bit
            if high_bit:        # If it overflows
                a ^= 0x13       # Reduce with S-AES irreducible polynomial x^4 + x + 1 (0x13)
            a &= 0xF            # Keep a within 4 bits
            b >>= 1             # Shift b right by 1 bit
        return result

    def mix_columns(self, state: list, inverse: bool = False) -> list:
        """
        This applies a matrix on the 16-bit state,
        multiplying each column by the matrix

        Args:
            state: list of 4 nibbles representing the state
            inverse: bool, if True, applies the inverse matrix
        Returns:
            new_state: list
        """

        print(f"\n→ Mixing columns:")

        if inverse:
            matrix = [[0x9, 0x2], [0x2, 0x9]]
        else:
            matrix = [[0x1, 0x4], [0x4, 0x1]]
        state_matrix = [[state[0], state[1]], [state[2], state[3]]]

        result = [[0, 0], [0, 0]]
        for i in range(2):
            for j in range(2):
                for k in range(2):
                    result[i][j] ^= self.gf_multiply(matrix[i][k], state_matrix[k][j])
        new_state = [result[0][0], result[0][1], result[1][0], result[1][1]]

        print(f"← Mix Columns complete")
        return new_state

    def encrypt(self, bits: int, key: int) -> int:
        """
        This encrypts a 16-bit integer using SAES

        Args:
            bits: int, 16-bit integer to encrypt
            key: int, 16-bit key for encryption
        Returns:
            encrypted_bits: int, 16-bit encrypted integer
        """

        print("=" * 50)
        print(f"→ Starting simple encryption")
        print(f"bits: {bits:04X}")
        print(f"key: {key:04X}")

        state = [
            (bits >> 12) & 0xF,  # nibble 0
            (bits >> 8) & 0xF,   # nibble 1
            (bits >> 4) & 0xF,   # nibble 2
            bits & 0xF           # nibble 3
        ]

        self.print_state(state, "initial bits state")
        # Expand the keys
        key0, round_key1, round_key2 = self.expand_key(key)

        # Round 0: AddRoundKey
        print(f"\n{'='*20} ROUND 0 {'='*20}")
        state = self.add_round_key(state, key0)
        self.print_state(state, "After Add Round Key")

        # Round 1: SubstituteNibbles with state, ShiftRows, MixColumns, AddRoundKey
        print(f"\n{'='*20} ROUND 1 {'='*20}")
        state = self.substitute_nibbles(state, self.sbox)
        state = self.shift_rows(state)
        state = self.mix_columns(state)
        state = self.add_round_key(state, round_key1)
        self.print_state(state, "State after Round 1")

        # Round 2: SubstituteNibbles with state, ShiftRows, AddRoundKey
        print(f"\n{'='*20} ROUND 2 {'='*20}")
        state = self.substitute_nibbles(state, self.sbox)
        state = self.shift_rows(state)
        state = self.add_round_key(state, round_key2)
        self.print_state(state, "State after Round 2")

        # Final output
        ciphertext = (state[0] << 12) | (state[1] << 8) | (state[2] << 4) | state[3]

        print(f"← Simple encryption complete")
        print("=" * 50)
        return ciphertext

    def encrypt_ecb(self, plaintext: str | int, key: int) -> dict:
        """
        Encrypts bits or a string using SAES in ECB mode.
        It creates 16-bit blocks from the input and encrypts each block separately.

        Args:
            plaintext: str or int, the input to encrypt
            key: int, the 16-bit key for encryption

        Returns:
            bits: blocks of encrypted 16-bit integers
            text: string based on the encrypted bits
            base64_text: base64 encoded string of the encrypted bits
            hex_text: hexadecimal string of the encrypted bits
        """
        print("=" * 50)
        if isinstance(plaintext, int):
            print(f"→ Encrypting string: '{plaintext:04X}'")

            # Split the integer into 16-bit blocks
            blocks = []
            temp = plaintext
            while temp > 0:
                blocks.append(temp & 0xFFFF) # Get last 16 bits
                temp >>= 16
            if not blocks:
                blocks = [0]
            # No padding needed for int
            blocks.reverse() # Reverse to maintain original order

        elif isinstance(plaintext, str):
            print(f"→ Encrypting string: '{plaintext}'")

            # Convert string to bytes
            data = plaintext.encode('utf-8')
            padding_len = 2 - (len(data) % 2)
            if padding_len == 2:
                padding_len = 0

            padding = bytes([padding_len]) * padding_len
            data += padding

            blocks = []
            for i in range(0, len(data), 2):
                block = int.from_bytes(data[i:i+2], 'big')
                blocks.append(block)

        # Encrypt each block
        encrypted_blocks = [self.encrypt(block, key) for block in blocks]
        # Turn blocks into a single integer
        all_bytes = b''.join(block.to_bytes(2, 'big') for block in encrypted_blocks)

        print(f"← ECB Encryption complete")

        return {
            'bits' :  encrypted_blocks,
            'base64_text' : base64.b64encode(all_bytes).decode('utf-8'),
            'hex_text' : ', '.join(f'{block:04X}' for block in encrypted_blocks)
        }

    def decrypt(self, ciphertext: int, key: int) -> int:
        """
        This decrypts a 16-bit integer using SAES

        Args:
            bits: int, 16-bit integer to decrypt
            key: int, 16-bit key for decryption
        Returns:
            decrypted_bits: int, 16-bit decrypted integer
        """

        print("=" * 50)
        print(f"→ Starting simple decryption")
        print(f"bits: {ciphertext:04X}")
        print(f"key: {key:04X}")

        state = [
            (ciphertext >> 12) & 0xF,  # nibble 0
            (ciphertext >> 8) & 0xF,   # nibble 1
            (ciphertext >> 4) & 0xF,   # nibble 2
            ciphertext & 0xF           # nibble 3
        ]

        self.print_state(state, "initial bits state")

        # Expand the keys
        key0, round_key1, round_key2 = self.expand_key(key)

        # Reverse Round 2: AddRoundKey, ShiftRows, SubstituteNibbles
        print(f"\n{'='*20} INVERSE ROUND 2 {'='*20}")
        state = self.add_round_key(state, round_key2)
        state = self.shift_rows(state)
        state = self.substitute_nibbles(state, self.inv_sbox)
        self.print_state(state, "State after inverse Round 2")

        # Reverse Round 1: AddRoundKey, MixColumns, ShiftRows, SubstituteNibbles
        print(f"\n{'='*20} INVERSE ROUND 1 {'='*20}")
        state = self.add_round_key(state, round_key1)
        state = self.mix_columns(state, inverse=True)
        state = self.shift_rows(state)
        state = self.substitute_nibbles(state, self.inv_sbox)
        self.print_state(state, "State after inverse Round 1")

        # Reverse Round 0: AddRoundKey
        print(f"\n{'='*20} INVERSE ROUND 0 {'='*20}")
        state = self.add_round_key(state, key0)
        self.print_state(state, "State after inverse Round 0")

        # convert state back to 16-bit integer
        plaintext = (state[0] << 12) | (state[1] << 8) | (state[2] << 4) | state[3]
        return plaintext

    def decrypt_ecb(self, ciphertext: list, key: int) -> dict:
        """
        Decrypts a list of 16-bit blocks using SAES.
        Args:
            ciphertext: list, the encrypted data to decrypt
            key: int, the 16-bit key for decryption

        Returns:
            decrypted_bits: int or list, the decrypted 16-bit integer(s)
            decrypted_text: str, the decrypted string
        """
        print("=" * 50)
        print(f"→ Decrypting {len(ciphertext)} blocks")

        decrypted_blocks = [self.decrypt(block, key) for block in ciphertext]
        # Convert decrypted blocks to bytes
        all_bytes = b''.join(block.to_bytes(2, 'big') for block in decrypted_blocks)

        # Decode bytes to string, ignoring padding
        decrypted_text = all_bytes.decode('utf-8', errors='ignore')#.rstrip('\x00')
        print(f"← ECB Decryption complete")

        return {
            'decrypted_bits': decrypted_blocks,
            'decrypted_text': decrypted_text
        }

# %%
saes = SAES()
bits = 0b1101001011010011
text = "This is an encrypted message for SAES testing."
key =       0b1101001010011010

# %% [markdown]
# ## Análise do resultados
# Testando os resultados com implementação simples e com strings em modo de operação ECB

# %%
ciphertext_bits = saes.encrypt(bits, key)
decrypted_bits = saes.decrypt(ciphertext_bits, key)

# Print results
print(f"\n{'='*20} RESULTS {'='*20}")
print(f"SAES Encryption and Decryption")
print(f"Key: {key:04X}")
print(f"Bits: {bits:04X}")
print(f"Ciphertext bits: {ciphertext_bits:04X}")
print(f"Decrypted bits: {decrypted_bits:04X}")
# Out:
# ==================================================
# → Starting simple encryption
# bits: D2D3
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0D  │ 02  │
# ├─────┼─────┤
# │ 0D  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 00  │ 00  │
# ├─────┼─────┤
# │ 04  │ 09  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 04  │ 04  │
# ├─────┼─────┤
# │ 0C  │ 09  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 03  │ 0D  │
# ├─────┼─────┤
# │ 00  │ 0A  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple decryption
# bits: 3D0A
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 03  │ 0D  │
# ├─────┼─────┤
# │ 00  │ 0A  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 04  │ 04  │
# ├─────┼─────┤
# │ 0C  │ 09  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 00  │ 00  │
# ├─────┼─────┤
# │ 04  │ 09  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 0D  │ 02  │
# ├─────┼─────┤
# │ 0D  │ 03  │
# └─────┴─────┘
#
# ==================== RESULTS ====================
# SAES Encryption and Decryption
# Key: D29A
# Bits: D2D3
# Ciphertext bits: 3D0A
# Decrypted bits: D2D3

# %%
ciphertext = saes.encrypt_ecb(text, key)
decrypted = saes.decrypt_ecb(ciphertext['bits'], key)
# Out:
# ==================================================
# → Encrypting string: 'This is an encrypted message for SAES testing.'
# ==================================================
# → Starting simple encryption
# bits: 5468
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 05  │ 04  │
# ├─────┼─────┤
# │ 06  │ 08  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 08  │ 06  │
# ├─────┼─────┤
# │ 0F  │ 02  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0D  │ 0B  │
# ├─────┼─────┤
# │ 0D  │ 07  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 00  │ 03  │
# ├─────┼─────┤
# │ 07  │ 08  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6973
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 09  │
# ├─────┼─────┤
# │ 07  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 0B  │
# ├─────┼─────┤
# │ 0E  │ 09  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0E  │ 06  │
# ├─────┼─────┤
# │ 02  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 01  │ 08  │
# ├─────┼─────┤
# │ 03  │ 0C  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 2069
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 09  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 03  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 08  │ 09  │
# ├─────┼─────┤
# │ 08  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 08  │ 02  │
# ├─────┼─────┤
# │ 05  │ 00  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7320
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 02  │ 00  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0A  │ 01  │
# ├─────┼─────┤
# │ 0B  │ 0A  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 05  │ 04  │
# ├─────┼─────┤
# │ 0C  │ 06  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0F  │ 0D  │
# ├─────┼─────┤
# │ 0A  │ 0A  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 616E
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 01  │
# ├─────┼─────┤
# │ 06  │ 0E  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 03  │
# ├─────┼─────┤
# │ 0F  │ 04  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 07  │ 08  │
# ├─────┼─────┤
# │ 0D  │ 0B  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0B  │ 06  │
# ├─────┼─────┤
# │ 01  │ 08  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 2065
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 05  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0D  │ 09  │
# ├─────┼─────┤
# │ 04  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 00  │ 02  │
# ├─────┼─────┤
# │ 05  │ 0B  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6E63
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 0E  │
# ├─────┼─────┤
# │ 06  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 0C  │
# ├─────┼─────┤
# │ 0F  │ 09  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0E  │ 0F  │
# ├─────┼─────┤
# │ 02  │ 04  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 01  │ 07  │
# ├─────┼─────┤
# │ 0F  │ 0C  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7279
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 02  │
# ├─────┼─────┤
# │ 07  │ 09  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0A  │ 00  │
# ├─────┼─────┤
# │ 0E  │ 03  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0F  │ 0C  │
# ├─────┼─────┤
# │ 07  │ 0B  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 09  │ 0C  │
# ├─────┼─────┤
# │ 01  │ 03  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7074
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 00  │
# ├─────┼─────┤
# │ 07  │ 04  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0A  │ 02  │
# ├─────┼─────┤
# │ 0E  │ 0E  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0C  │ 0F  │
# ├─────┼─────┤
# │ 03  │ 07  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 02  │ 07  │
# ├─────┼─────┤
# │ 07  │ 0D  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6564
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 05  │
# ├─────┼─────┤
# │ 06  │ 04  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 07  │
# ├─────┼─────┤
# │ 0F  │ 0E  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0F  │ 06  │
# ├─────┼─────┤
# │ 0F  │ 06  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 09  │ 08  │
# ├─────┼─────┤
# │ 0A  │ 01  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 206D
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 0D  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 07  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 05  │ 09  │
# ├─────┼─────┤
# │ 06  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 05  │ 0E  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6573
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 05  │
# ├─────┼─────┤
# │ 07  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 07  │
# ├─────┼─────┤
# │ 0E  │ 09  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0E  │ 00  │
# ├─────┼─────┤
# │ 02  │ 0E  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 01  │ 09  │
# ├─────┼─────┤
# │ 0D  │ 0C  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7361
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 06  │ 01  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0A  │ 01  │
# ├─────┼─────┤
# │ 0F  │ 0B  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 09  │ 07  │
# ├─────┼─────┤
# │ 0F  │ 02  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0C  │ 05  │
# ├─────┼─────┤
# │ 08  │ 01  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6765
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 07  │
# ├─────┼─────┤
# │ 06  │ 05  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 05  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 09  │ 02  │
# ├─────┼─────┤
# │ 07  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0C  │ 0A  │
# ├─────┼─────┤
# │ 03  │ 03  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 2066
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 06  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 0C  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 07  │ 09  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0B  │ 02  │
# ├─────┼─────┤
# │ 05  │ 01  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6F72
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 0F  │
# ├─────┼─────┤
# │ 07  │ 02  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 0D  │
# ├─────┼─────┤
# │ 0E  │ 08  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0D  │ 0B  │
# ├─────┼─────┤
# │ 06  │ 04  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 00  │ 03  │
# ├─────┼─────┤
# │ 0F  │ 0E  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 2053
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 05  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0C  │ 09  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0A  │ 03  │
# ├─────┼─────┤
# │ 01  │ 04  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0E  │ 0B  │
# ├─────┼─────┤
# │ 0F  │ 02  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 4145
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 04  │ 01  │
# ├─────┼─────┤
# │ 04  │ 05  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 09  │ 03  │
# ├─────┼─────┤
# │ 0D  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 08  │ 0A  │
# ├─────┼─────┤
# │ 03  │ 02  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 08  │ 00  │
# ├─────┼─────┤
# │ 08  │ 0D  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 5320
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 05  │ 03  │
# ├─────┼─────┤
# │ 02  │ 00  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 08  │ 01  │
# ├─────┼─────┤
# │ 0B  │ 0A  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 03  │ 04  │
# ├─────┼─────┤
# │ 07  │ 06  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 05  │ 0D  │
# ├─────┼─────┤
# │ 0A  │ 03  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7465
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 04  │
# ├─────┼─────┤
# │ 06  │ 05  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0A  │ 06  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0A  │ 0B  │
# ├─────┼─────┤
# │ 0B  │ 07  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0E  │ 03  │
# ├─────┼─────┤
# │ 07  │ 05  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7374
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 07  │ 04  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0A  │ 01  │
# ├─────┼─────┤
# │ 0E  │ 0E  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0C  │ 01  │
# ├─────┼─────┤
# │ 03  │ 0A  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 02  │ 04  │
# ├─────┼─────┤
# │ 02  │ 0D  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 696E
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 09  │
# ├─────┼─────┤
# │ 06  │ 0E  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 0B  │
# ├─────┼─────┤
# │ 0F  │ 04  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 07  │ 00  │
# ├─────┼─────┤
# │ 0D  │ 0D  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0B  │ 09  │
# ├─────┼─────┤
# │ 0C  │ 08  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 672E
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 07  │
# ├─────┼─────┤
# │ 02  │ 0E  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 0B  │ 05  │
# ├─────┼─────┤
# │ 0B  │ 04  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 07  │ 01  │
# ├─────┼─────┤
# │ 0D  │ 01  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0B  │ 04  │
# ├─────┼─────┤
# │ 06  │ 08  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ← ECB Encryption complete
# ==================================================
# → Decrypting 23 blocks
# ==================================================
# → Starting simple decryption
# bits: 0378
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 00  │ 03  │
# ├─────┼─────┤
# │ 07  │ 08  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0D  │ 0B  │
# ├─────┼─────┤
# │ 0D  │ 07  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 08  │ 06  │
# ├─────┼─────┤
# │ 0F  │ 02  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 05  │ 04  │
# ├─────┼─────┤
# │ 06  │ 08  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 183C
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 01  │ 08  │
# ├─────┼─────┤
# │ 03  │ 0C  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0E  │ 06  │
# ├─────┼─────┤
# │ 02  │ 05  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 0B  │
# ├─────┼─────┤
# │ 0E  │ 09  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 09  │
# ├─────┼─────┤
# │ 07  │ 03  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 8250
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 08  │ 02  │
# ├─────┼─────┤
# │ 05  │ 00  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 08  │ 09  │
# ├─────┼─────┤
# │ 08  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 03  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 09  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: FDAA
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0F  │ 0D  │
# ├─────┼─────┤
# │ 0A  │ 0A  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 05  │ 04  │
# ├─────┼─────┤
# │ 0C  │ 06  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0A  │ 01  │
# ├─────┼─────┤
# │ 0B  │ 0A  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 02  │ 00  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: B618
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0B  │ 06  │
# ├─────┼─────┤
# │ 01  │ 08  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 07  │ 08  │
# ├─────┼─────┤
# │ 0D  │ 0B  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 03  │
# ├─────┼─────┤
# │ 0F  │ 04  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 01  │
# ├─────┼─────┤
# │ 06  │ 0E  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 025B
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 00  │ 02  │
# ├─────┼─────┤
# │ 05  │ 0B  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0D  │ 09  │
# ├─────┼─────┤
# │ 04  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 05  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 17FC
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 01  │ 07  │
# ├─────┼─────┤
# │ 0F  │ 0C  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0E  │ 0F  │
# ├─────┼─────┤
# │ 02  │ 04  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 0C  │
# ├─────┼─────┤
# │ 0F  │ 09  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 0E  │
# ├─────┼─────┤
# │ 06  │ 03  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 9C13
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 09  │ 0C  │
# ├─────┼─────┤
# │ 01  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0F  │ 0C  │
# ├─────┼─────┤
# │ 07  │ 0B  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0A  │ 00  │
# ├─────┼─────┤
# │ 0E  │ 03  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 07  │ 02  │
# ├─────┼─────┤
# │ 07  │ 09  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 277D
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 07  │
# ├─────┼─────┤
# │ 07  │ 0D  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0C  │ 0F  │
# ├─────┼─────┤
# │ 03  │ 07  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0A  │ 02  │
# ├─────┼─────┤
# │ 0E  │ 0E  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 07  │ 00  │
# ├─────┼─────┤
# │ 07  │ 04  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 98A1
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 09  │ 08  │
# ├─────┼─────┤
# │ 0A  │ 01  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0F  │ 06  │
# ├─────┼─────┤
# │ 0F  │ 06  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 07  │
# ├─────┼─────┤
# │ 0F  │ 0E  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 05  │
# ├─────┼─────┤
# │ 06  │ 04  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: F25E
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 05  │ 0E  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 05  │ 09  │
# ├─────┼─────┤
# │ 06  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 07  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 0D  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 19DC
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 01  │ 09  │
# ├─────┼─────┤
# │ 0D  │ 0C  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0E  │ 00  │
# ├─────┼─────┤
# │ 02  │ 0E  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 07  │
# ├─────┼─────┤
# │ 0E  │ 09  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 05  │
# ├─────┼─────┤
# │ 07  │ 03  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: C581
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0C  │ 05  │
# ├─────┼─────┤
# │ 08  │ 01  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 09  │ 07  │
# ├─────┼─────┤
# │ 0F  │ 02  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0A  │ 01  │
# ├─────┼─────┤
# │ 0F  │ 0B  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 06  │ 01  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: CA33
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0C  │ 0A  │
# ├─────┼─────┤
# │ 03  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 09  │ 02  │
# ├─────┼─────┤
# │ 07  │ 05  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 05  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 07  │
# ├─────┼─────┤
# │ 06  │ 05  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: B251
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0B  │ 02  │
# ├─────┼─────┤
# │ 05  │ 01  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 07  │ 09  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0F  │ 0C  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 06  │ 06  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 03FE
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 00  │ 03  │
# ├─────┼─────┤
# │ 0F  │ 0E  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0D  │ 0B  │
# ├─────┼─────┤
# │ 06  │ 04  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 0D  │
# ├─────┼─────┤
# │ 0E  │ 08  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 0F  │
# ├─────┼─────┤
# │ 07  │ 02  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: EBF2
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0E  │ 0B  │
# ├─────┼─────┤
# │ 0F  │ 02  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0A  │ 03  │
# ├─────┼─────┤
# │ 01  │ 04  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0F  │ 02  │
# ├─────┼─────┤
# │ 0C  │ 09  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 02  │ 00  │
# ├─────┼─────┤
# │ 05  │ 03  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 808D
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 08  │ 00  │
# ├─────┼─────┤
# │ 08  │ 0D  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 08  │ 0A  │
# ├─────┼─────┤
# │ 03  │ 02  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 09  │ 03  │
# ├─────┼─────┤
# │ 0D  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 04  │ 01  │
# ├─────┼─────┤
# │ 04  │ 05  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 5DA3
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 05  │ 0D  │
# ├─────┼─────┤
# │ 0A  │ 03  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 03  │ 04  │
# ├─────┼─────┤
# │ 07  │ 06  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 08  │ 01  │
# ├─────┼─────┤
# │ 0B  │ 0A  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 05  │ 03  │
# ├─────┼─────┤
# │ 02  │ 00  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: E375
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0E  │ 03  │
# ├─────┼─────┤
# │ 07  │ 05  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0A  │ 0B  │
# ├─────┼─────┤
# │ 0B  │ 07  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0A  │ 06  │
# ├─────┼─────┤
# │ 0F  │ 0F  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 07  │ 04  │
# ├─────┼─────┤
# │ 06  │ 05  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: 242D
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 02  │ 04  │
# ├─────┼─────┤
# │ 02  │ 0D  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 0C  │ 01  │
# ├─────┼─────┤
# │ 03  │ 0A  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0A  │ 01  │
# ├─────┼─────┤
# │ 0E  │ 0E  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 07  │ 04  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: B9C8
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0B  │ 09  │
# ├─────┼─────┤
# │ 0C  │ 08  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 07  │ 00  │
# ├─────┼─────┤
# │ 0D  │ 0D  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 0B  │
# ├─────┼─────┤
# │ 0F  │ 04  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 09  │
# ├─────┼─────┤
# │ 06  │ 0E  │
# └─────┴─────┘
# ==================================================
# → Starting simple decryption
# bits: B468
# key: D29A
# initial bits state:
# ┌─────┬─────┐
# │ 0B  │ 04  │
# ├─────┼─────┤
# │ 06  │ 08  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: D29A
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== INVERSE ROUND 2 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 2:
# ┌─────┬─────┐
# │ 07  │ 01  │
# ├─────┼─────┤
# │ 0D  │ 01  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 1 ====================
#
# → Adding round key:
# ← Add Round Key complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Substituting nibbles:
# ← Substitution complete
# State after inverse Round 1:
# ┌─────┬─────┐
# │ 0B  │ 05  │
# ├─────┼─────┤
# │ 0B  │ 04  │
# └─────┴─────┘
#
# ==================== INVERSE ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# State after inverse Round 0:
# ┌─────┬─────┐
# │ 06  │ 07  │
# ├─────┼─────┤
# │ 02  │ 0E  │
# └─────┴─────┘
# ← ECB Decryption complete

# %%
# Split because of enormous output
print(f"\n{'='*20} RESULTS {'='*20}")
print(f"SAES ECB Encryption and Decryption Results")
print(f"Key: {key:04X}")
print(f"Text: {text}")
print(f"Ciphertext bits: {[f'0x{b:04X}' for b in ciphertext['bits']]}")
print(f"Ciphertext base64: {ciphertext['base64_text']}")
print(f"Ciphertext hex: {ciphertext['hex_text']}")
print("-" * 50)
print(f"Decrypted bits: {[f'0x{b:04X}' for b in decrypted['decrypted_bits']]}")
print(f"Decrypted text: {decrypted['decrypted_text']}")
print("=" * 50)
# Out:
# ==================== RESULTS ====================
# SAES ECB Encryption and Decryption Results
# Key: D29A
# Text: This is an encrypted message for SAES testing.
# Ciphertext bits: ['0x0378', '0x183C', '0x8250', '0xFDAA', '0xB618', '0x025B', '0x17FC', '0x9C13', '0x277D', '0x98A1', '0xF25E', '0x19DC', '0xC581', '0xCA33', '0xB251', '0x03FE', '0xEBF2', '0x808D', '0x5DA3', '0xE375', '0x242D', '0xB9C8', '0xB468']
# Ciphertext base64: A3gYPIJQ/aq2GAJbF/ycEyd9mKHyXhncxYHKM7JRA/7r8oCNXaPjdSQtuci0aA==
# Ciphertext hex: 0378, 183C, 8250, FDAA, B618, 025B, 17FC, 9C13, 277D, 98A1, F25E, 19DC, C581, CA33, B251, 03FE, EBF2, 808D, 5DA3, E375, 242D, B9C8, B468
# --------------------------------------------------
# Decrypted bits: ['0x5468', '0x6973', '0x2069', '0x7320', '0x616E', '0x2065', '0x6E63', '0x7279', '0x7074', '0x6564', '0x206D', '0x6573', '0x7361', '0x6765', '0x2066', '0x6F72', '0x2053', '0x4145', '0x5320', '0x7465', '0x7374', '0x696E', '0x672E']
# Decrypted text: This is an encrypted message for SAES testing.
# ==================================================

# %%
ecb_text = "attackattack"
key_ecb = 0x1234
encrypt_demo = saes.encrypt_ecb(ecb_text, key_ecb)
# Out:
# ==================================================
# → Encrypting string: 'attackattack'
# ==================================================
# → Starting simple encryption
# bits: 6174
# key: 1234
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 01  │
# ├─────┼─────┤
# │ 07  │ 04  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: 1234
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 04  │ 00  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 03  │ 0C  │
# ├─────┼─────┤
# │ 09  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 06  │ 0F  │
# ├─────┼─────┤
# │ 0B  │ 03  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7461
# key: 1234
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 04  │
# ├─────┼─────┤
# │ 06  │ 01  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: 1234
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 06  │ 06  │
# ├─────┼─────┤
# │ 05  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 08  │ 0A  │
# ├─────┼─────┤
# │ 00  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0B  │ 03  │
# ├─────┼─────┤
# │ 0B  │ 08  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 636B
# key: 1234
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 03  │
# ├─────┼─────┤
# │ 06  │ 0B  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: 1234
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 07  │ 01  │
# ├─────┼─────┤
# │ 05  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0E  │ 06  │
# ├─────┼─────┤
# │ 07  │ 00  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 02  │ 0B  │
# ├─────┼─────┤
# │ 03  │ 04  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 6174
# key: 1234
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 01  │
# ├─────┼─────┤
# │ 07  │ 04  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: 1234
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 07  │ 03  │
# ├─────┼─────┤
# │ 04  │ 00  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 03  │ 0C  │
# ├─────┼─────┤
# │ 09  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 06  │ 0F  │
# ├─────┼─────┤
# │ 0B  │ 03  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 7461
# key: 1234
# initial bits state:
# ┌─────┬─────┐
# │ 07  │ 04  │
# ├─────┼─────┤
# │ 06  │ 01  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: 1234
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 06  │ 06  │
# ├─────┼─────┤
# │ 05  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 08  │ 0A  │
# ├─────┼─────┤
# │ 00  │ 05  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 0B  │ 03  │
# ├─────┼─────┤
# │ 0B  │ 08  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ==================================================
# → Starting simple encryption
# bits: 636B
# key: 1234
# initial bits state:
# ┌─────┬─────┐
# │ 06  │ 03  │
# ├─────┼─────┤
# │ 06  │ 0B  │
# └─────┴─────┘
#
#
# → Starting key expansion with key: 1234
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Substituting nibbles:
# ← Substitution complete
# ← Key expansion complete
#
# ==================== ROUND 0 ====================
#
# → Adding round key:
# ← Add Round Key complete
# After Add Round Key:
# ┌─────┬─────┐
# │ 07  │ 01  │
# ├─────┼─────┤
# │ 05  │ 0F  │
# └─────┴─────┘
#
# ==================== ROUND 1 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Mixing columns:
# ← Mix Columns complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 1:
# ┌─────┬─────┐
# │ 0E  │ 06  │
# ├─────┼─────┤
# │ 07  │ 00  │
# └─────┴─────┘
#
# ==================== ROUND 2 ====================
#
# → Substituting nibbles:
# ← Substitution complete
#
# → Shifting rows:
# ← Shift Rows complete
#
# → Adding round key:
# ← Add Round Key complete
# State after Round 2:
# ┌─────┬─────┐
# │ 02  │ 0B  │
# ├─────┼─────┤
# │ 03  │ 04  │
# └─────┴─────┘
# ← Simple encryption complete
# ==================================================
# ← ECB Encryption complete

# %%
print(f"\n{'='*20} Demo de Fraqueza ECB {'='*20}")
print(f"Plaintext: {ecb_text}")
print(f"Key: {key_ecb:04X}")
print(f"-"*50)
print(f"Ciphertext Hex: {encrypt_demo['hex_text']}")
# Out:
# ==================== Demo de Fraqueza ECB ====================
# Plaintext: attackattack
# Key: 1234
# --------------------------------------------------
# Ciphertext Hex: 6FB3, B3B8, 2B34, 6FB3, B3B8, 2B34

# %% [markdown]
# ### Percebendo fraqueza do modo ECB
# Ao utilizar o modo de operação ECB, que cifra cada bloco separadamente, é possível perceber a repetição de padrões, "attackattack" é basicamente uma frase simétrica espelhada na cifra, o que abre portas para detecção de padrões para uma pessoa tentando decifrar a mensagem.

# %% [markdown]
# # Parte 3: Simulação AES usando bibliotecas criptográficas
# Utilizando a biblioteca PyCryptoDome para simular o AES real com os seguintes modos de operação:
# - ECB
# - CBC
# - CFB
# - OFB
# - CTR
#
# Para cada saída, serão usados a mesma mensagem e vetor de inicialização, e serão analisados o tempo de execução e grau de aleatoriedade, apresentando as saídas em base64

# %%
# !pip install pycryptodome
# Out:
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.11/dist-packages (3.23.0)

# %%
import zlib
import time
import math
import base64
from Crypto.Cipher import AES
from collections import Counter
from Crypto.Random import get_random_bytes
from Crypto.Util.Padding import pad, unpad

# %%
mensagem = "Isso é uma mensagem longa para ser cifrada utilizando AES em diferentes modos de operação. Boa sorte para me cifrar!"
plaintext = mensagem.encode('utf-8')
key = get_random_bytes(16) # Chave de 16-bytes ou 128-bits

def measure_random(plaintext_bytes, ciphertext_bytes, block_size=16):
    """
    This measures randomness degree from different modes of operation

    Args:
        mode (str): operation mode
        plaintext_bytes (bytes): original plaintext bytes
        ciphertext_bytes (bytes): ciphertext bytes
        block_size (int, optional): block size for AES. Defaults to 16.
    """
    print(f"\n===== Medida de aleatoriedade =====")

    # Entropia (mede incerteza/aleatoriedade)
    counts = Counter(ciphertext_bytes)
    entropy = -sum((
        count / len(ciphertext_bytes)) *
                   math.log2(count / len(ciphertext_bytes))
                   for count in counts.values())

    print(f"Entropia (bits): {entropy:.4f}")

# %% [markdown]
# ## Modo Básico de Operação ECB (Eletronic Codebook)
# Modo que divide o texto em blocos de 128 bits e cifra cada bloco individualmente, não tão seguro por causa do *vazamento de padrões*

# %%
start = time.time() # Taking initial time
# Implementing AES function with 128-bit key
cipher = AES.new(key, AES.MODE_ECB)
ciphertext = cipher.encrypt(pad(plaintext, AES.block_size))
end = time.time() # Taking final time

print(f"\n===== Resultado ECB =====" )
print(f"Texto original: '{mensagem}'")
print(f"Texto em base64: {base64.b64encode(plaintext).decode()}")
print("-"*50)
print(f"Ciphertext (Base64): {base64.b64encode(ciphertext).decode()}")
print(f"Tempo de execução: {(end - start)*1000:.2f} ms") # elapsed time
measure_random(plaintext, ciphertext)
# Out:
# ===== Resultado ECB =====
# Texto original: 'Isso é uma mensagem longa para ser cifrada utilizando AES em diferentes modos de operação. Boa sorte para me cifrar!'
# Texto em base64: SXNzbyDDqSB1bWEgbWVuc2FnZW0gbG9uZ2EgcGFyYSBzZXIgY2lmcmFkYSB1dGlsaXphbmRvIEFFUyBlbSBkaWZlcmVudGVzIG1vZG9zIGRlIG9wZXJhw6fDo28uIEJvYSBzb3J0ZSBwYXJhIG1lIGNpZnJhciE=
# --------------------------------------------------
# Ciphertext (Base64): nkm7TJBzUUsJC49IE2VGhVLY/PPT7sLzw98oaOJrBhPXr94h+sRtUyy1HYjFuoZwjYd5kdYH+tz4mG4DlH66vMembJGHBzlEiATSJnTeeMkYeVRuM/kek2t9MAyXgZkueVVBAIR1ksJxXlayH5c15mIrNw24Z5+6wli2U7MFLWQ=
# Tempo de execução: 0.33 ms
#
# ===== Medida de aleatoriedade =====
# Entropia (bits): 6.7011

# %% [markdown]
# ## Modo CBC (Cipher Block Chaining)
# Antes de cifrar, cada bloco de 128 bits é feito um **XOR com o bloco cifrado anterior**. O primeiro bloco é combinado com o vetor de inicialização de 128 bits. Isso adiciona entropia ao modo de operação.

# %%
# First, create a initial vector
start = time.time() # Taking initial time
iv = get_random_bytes(AES.block_size) # 16 byte block size
cipher = AES.new(key, AES.MODE_CBC, iv)
ciphertext = cipher.encrypt(pad(plaintext, AES.block_size))
end = time.time() # Taking final time

print(f"\n===== Resultado CBC =====" )
print(f"Texto original: '{mensagem}'")
print(f"Texto em base64: {base64.b64encode(plaintext).decode()}")
print("-"*50)
print(f"Vetor de inicialização (Base64): {base64.b64encode(iv).decode()}")
print(f"Ciphertext (Base64): {base64.b64encode(ciphertext).decode()}")
print(f"Tempo de execução: {(end - start)*1000:.2f} ms") # elapsed time
measure_random(plaintext, ciphertext)
# Out:
# ===== Resultado CBC =====
# Texto original: 'Isso é uma mensagem longa para ser cifrada utilizando AES em diferentes modos de operação. Boa sorte para me cifrar!'
# Texto em base64: SXNzbyDDqSB1bWEgbWVuc2FnZW0gbG9uZ2EgcGFyYSBzZXIgY2lmcmFkYSB1dGlsaXphbmRvIEFFUyBlbSBkaWZlcmVudGVzIG1vZG9zIGRlIG9wZXJhw6fDo28uIEJvYSBzb3J0ZSBwYXJhIG1lIGNpZnJhciE=
# --------------------------------------------------
# Vetor de inicialização (Base64): PkaBdY8Fo/QBlpy1z6lF0A==
# Ciphertext (Base64): iI0n/8FJ3vlE+2uc3EMpqDM51UDdnVPHd8f3ZFfIVqtXoZu9plmXXdPhiL3mLheDgNQwpz32qFo/Ox2+ToCMchUwhVg6eYM+NXeJe4Epr3in2Vst1swzZC/WdL+MKBj787j7Cb2CkpJQNDmCh2sdDysW0zjJjNKfM+lC27SqSPQ=
# Tempo de execução: 0.46 ms
#
# ===== Medida de aleatoriedade =====
# Entropia (bits): 6.5702

# %% [markdown]
# ## Modo CFB (Cipher Feedback)
# Esse é um modo de fluxo. A saída do AES aplicado ao IV é XOR com o primeiro bloco de plaintext. A seguir, a saída do AES aplicado ao bloco cifrado anterior (Cn−1) é XOR com o próximo bloco de plaintext (Pn). É um fluxo de cifragem com realimentação.

# %%
# First, create a initial vector
start = time.time() # Taking initial time
iv = get_random_bytes(AES.block_size) # 16 byte block size
cipher = AES.new(key, AES.MODE_CFB, iv, segment_size=128)
ciphertext = cipher.encrypt(pad(plaintext, AES.block_size))
end = time.time() # Taking final time

print(f"\n===== Resultado CFB =====" )
print(f"Texto original: '{mensagem}'")
print(f"Texto em base64: {base64.b64encode(plaintext).decode()}")
print("-"*50)
print(f"Vetor de inicialização (Base64): {base64.b64encode(iv).decode()}")
print(f"Ciphertext (Base64): {base64.b64encode(ciphertext).decode()}")
print(f"Tempo de execução: {(end - start)*1000:.2f} ms") # elapsed time
measure_random(plaintext, ciphertext)
# Out:
# ===== Resultado CFB =====
# Texto original: 'Isso é uma mensagem longa para ser cifrada utilizando AES em diferentes modos de operação. Boa sorte para me cifrar!'
# Texto em base64: SXNzbyDDqSB1bWEgbWVuc2FnZW0gbG9uZ2EgcGFyYSBzZXIgY2lmcmFkYSB1dGlsaXphbmRvIEFFUyBlbSBkaWZlcmVudGVzIG1vZG9zIGRlIG9wZXJhw6fDo28uIEJvYSBzb3J0ZSBwYXJhIG1lIGNpZnJhciE=
# --------------------------------------------------
# Vetor de inicialização (Base64): 01RoO5pMyAMbjMmDMj1EwA==
# Ciphertext (Base64): jHHvn12L57hQpUuUyfwotP7EWhgn/IHHAJjnS/gYNfAk+8aUlNIK0PynuQPv24aBsQXfwGqoRxbD2Tv0SF2qT/zUN3yB9km+Wr9AbGVpms/CFxiar0CZXLXB+zZHtDI9qDUa2p9kBfrzjzWM9sCtyiIG5rBs4EUPR9tAvMFC0DU=
# Tempo de execução: 0.43 ms
#
# ===== Medida de aleatoriedade =====
# Entropia (bits): 6.4080

# %% [markdown]
# ## Modo OFB (Output Feedback)
# Outro modo de fluxo, ele cifra repetidamente o IV, gerando blocos Oi = AES(Oi-1), que são combinados com o plaintext Pi com um XOR Ci = Oi ⊕ Pi. É necessário um IV único para que o keystream Oi sempre seja único.

# %%
# First, create a initial vector
start = time.time() # Taking initial time
iv = get_random_bytes(AES.block_size) # 16 byte block size
cipher = AES.new(key, AES.MODE_OFB, iv)
ciphertext = cipher.encrypt(plaintext)
end = time.time() # Taking final time

print(f"\n===== Resultado OFB =====" )
print(f"Texto original: '{mensagem}'")
print(f"Texto em base64: {base64.b64encode(plaintext).decode()}")
print("-"*50)
print(f"Vetor de inicialização (Base64): {base64.b64encode(iv).decode()}")
print(f"Ciphertext (Base64): {base64.b64encode(ciphertext).decode()}")
print(f"Tempo de execução: {(end - start)*1000:.2f} ms") # elapsed time
measure_random(plaintext, ciphertext)
# Out:
# ===== Resultado OFB =====
# Texto original: 'Isso é uma mensagem longa para ser cifrada utilizando AES em diferentes modos de operação. Boa sorte para me cifrar!'
# Texto em base64: SXNzbyDDqSB1bWEgbWVuc2FnZW0gbG9uZ2EgcGFyYSBzZXIgY2lmcmFkYSB1dGlsaXphbmRvIEFFUyBlbSBkaWZlcmVudGVzIG1vZG9zIGRlIG9wZXJhw6fDo28uIEJvYSBzb3J0ZSBwYXJhIG1lIGNpZnJhciE=
# --------------------------------------------------
# Vetor de inicialização (Base64): gRgbNBYhw/xHj50gG8kTzA==
# Ciphertext (Base64): Uyu/JY5mEUOQwSUIEdnSsdGmw90Wcy3TwUvex+AvJFiEKRyG2nkNK7F2RHje4fU29FD3sNIWfbDKksXwU+xaYi+n7XEotzBUkxJgbuhuavFyP82Y7YPz0cdXq6KtZUeUPtnIV5cx85mUDOUvYLvn7zxoEfc7WXY=
# Tempo de execução: 0.80 ms
#
# ===== Medida de aleatoriedade =====
# Entropia (bits): 6.4788

# %% [markdown]
# ## Modo CTR
# É iniciado um contador e um *Nonce* que são concatenados e cifrados, e então é feito um XOR com cada plaintext, gerando o ciphertext. A cada novo bloco, o contador é incrementado, para gerar um keystream diferente e cifrar um novo bloco de plaintext evitando padrões.

# %%
start = time.time() # Taking initial time
# Implementing AES function with 128-bit key
cipher = AES.new(key, AES.MODE_CTR)
ciphertext = cipher.encrypt(plaintext)
end = time.time() # Taking final time

print(f"\n===== Resultado CTR =====" )
print(f"Texto original: '{mensagem}'")
print(f"Texto em base64: {base64.b64encode(plaintext).decode()}")
print("-"*50)
print(f"Ciphertext (Base64): {base64.b64encode(ciphertext).decode()}")
print(f"Tempo de execução: {(end - start)*1000:.2f} ms") # elapsed time
measure_random(plaintext, ciphertext)
# Out:
# ===== Resultado CTR =====
# Texto original: 'Isso é uma mensagem longa para ser cifrada utilizando AES em diferentes modos de operação. Boa sorte para me cifrar!'
# Texto em base64: SXNzbyDDqSB1bWEgbWVuc2FnZW0gbG9uZ2EgcGFyYSBzZXIgY2lmcmFkYSB1dGlsaXphbmRvIEFFUyBlbSBkaWZlcmVudGVzIG1vZG9zIGRlIG9wZXJhw6fDo28uIEJvYSBzb3J0ZSBwYXJhIG1lIGNpZnJhciE=
# --------------------------------------------------
# Ciphertext (Base64): 1o4mdz1XNA0yaz/UFRWIP3KgA1njqyguZpoFuQAUyCKycyuU+Q2hDViK/SZb/Z1ETs+2/OBiqyNKsbjohmSSeAi1Bnn7swA/YsEfcHZANyxvRXHJW7Ul1FRmP/O1vPQF1FSoY+nncPYzuWgcy9wd8s+YNBR/zM8=
# Tempo de execução: 0.34 ms
#
# ===== Medida de aleatoriedade =====
# Entropia (bits): 6.4325
